# %%
import numpy as np
import pandas as pd

import warnings

warnings.filterwarnings("ignore")

# %%
# Load the dataset

df = pd.read_csv("car_prices.csv")

df.head()
# Out:
#    year   make                model        trim   body transmission  \
# 0  2015    Kia              Sorento          LX    SUV    automatic
# 1  2015    Kia              Sorento          LX    SUV    automatic
# 2  2014    BMW             3 Series  328i SULEV  Sedan    automatic
# 3  2015  Volvo                  S60          T5  Sedan    automatic
# 4  2014    BMW  6 Series Gran Coupe        650i  Sedan    automatic
#
#                  vin state  condition  odometer  color interior  \
# 0  5xyktca69fg566472    ca        5.0   16639.0  white    black
# 1  5xyktca69fg561319    ca        5.0    9393.0  white    beige
# 2  wba3c1c51ek116351    ca       45.0    1331.0   gray    black
# 3  yv1612tb4f1310987    ca       41.0   14282.0  white    black
# 4  wba6b2c57ed129731    ca       43.0    2641.0   gray    black
#
#                                    seller      mmr  sellingprice  \
# 0                 kia motors america  inc  20500.0       21500.0
# ...

# %%
df.shape

print(f"No. of Rows:{df.shape[0]},No. of Columns:{df.shape[1]}")
# Out:
# No. of Rows:558837,No. of Columns:16

# %%
# Drop irrelevant columns

df.drop("vin",axis = 1,inplace = True)

# %%
df.columns

print(f"No. of Rows:{df.shape[0]},No. of Columns:{df.shape[1]}")
# Out:
# No. of Rows:558837,No. of Columns:15

# %%
# Rename the Columns
df.rename({
    "year":"MFG Year",
    "make":"Brand",
    "model":"Model",
    "trim":"Designation",
    "body":"Body Type",
    "transmission":"Transmission",
    "state":"State",
    "condition":"Condition",
"odometer":"Odometer_reading",
"color":"Exterior_color",
"interior":"Interior_Color",
"seller":"Seller",
"mmr":"MMR",
"sellingprice":"Selling_price",
"saledate":"sale_date"}, axis = 1,inplace = True)

df.head()
# Out:
#    MFG Year  Brand                Model Designation Body Type Transmission  \
# 0      2015    Kia              Sorento          LX       SUV    automatic
# 1      2015    Kia              Sorento          LX       SUV    automatic
# 2      2014    BMW             3 Series  328i SULEV     Sedan    automatic
# 3      2015  Volvo                  S60          T5     Sedan    automatic
# 4      2014    BMW  6 Series Gran Coupe        650i     Sedan    automatic
#
#   State  Condition  Odometer_reading Exterior_color Interior_Color  \
# 0    ca        5.0           16639.0          white          black
# 1    ca        5.0            9393.0          white          beige
# 2    ca       45.0            1331.0           gray          black
# 3    ca       41.0           14282.0          white          black
# 4    ca       43.0            2641.0           gray          black
#
#                                    Seller      MMR  Selling_price  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 558837 entries, 0 to 558836
# Data columns (total 15 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   MFG Year          558837 non-null  int64
#  1   Brand             548536 non-null  object
#  2   Model             548438 non-null  object
#  3   Designation       548186 non-null  object
#  4   Body Type         545642 non-null  object
#  5   Transmission      493485 non-null  object
#  6   State             558837 non-null  object
#  7   Condition         547017 non-null  float64
#  8   Odometer_reading  558743 non-null  float64
#  9   Exterior_color    558088 non-null  object
#  10  Interior_Color    558088 non-null  object
#  11  Seller            558837 non-null  object
#  12  MMR               558799 non-null  float64
#  13  Selling_price     558825 non-null  float64
#  14  sale_date         558825 non-null  object
# dtypes: float64(4), int64(1), object(10)
# ...

# %%
df.isnull().sum()

Null_Counts = df.isnull().sum()
Null_percentage = df.isnull().sum()/len(df) * 100

print(f"Null Counts:{Null_Counts}")
print(f"Null %age:{Null_percentage}")
# Out:
# Null Counts:MFG Year                0
# Brand               10301
# Model               10399
# Designation         10651
# Body Type           13195
# Transmission        65352
# State                   0
# Condition           11820
# Odometer_reading       94
# Exterior_color        749
# Interior_Color        749
# Seller                  0
# MMR                    38
# Selling_price          12
# sale_date              12
# dtype: int64
# Null %age:MFG Year             0.000000
# Brand                1.843292
# Model                1.860829
# Designation          1.905922
# Body Type            2.361154
# Transmission        11.694287
# State                0.000000
# Condition            2.115107
# Odometer_reading     0.016821
# Exterior_color       0.134028
# Interior_Color       0.134028
# Seller               0.000000
# MMR                  0.006800
# Selling_price        0.002147
# sale_date            0.002147
# dtype: float64

# %%
df["Transmission"].isnull().sum()
# Out:
# np.int64(65352)

# %%
df["Transmission"].unique()
# Out:
# array(['automatic', nan, 'manual', 'Sedan', 'sedan'], dtype=object)

# %%
df["Transmission"].value_counts()
# Out:
# Transmission
# automatic    475915
# manual        17544
# sedan            15
# Sedan            11
# Name: count, dtype: int64

# %%
# Combining sedan and Sedan as they are same objects

# df.rename({"Sedan":"sedan"},axis = 0,inplace = True)

# df["Transmission"] = df["Transmission"]=="Sedan".cat(df["Transmission"]=="sedan")

# df["Transmission"].value_counts()

# df["Transmission"]=="Sedan"

# %%
df.drop(df[df["Transmission"]=="Sedan"].index, inplace=True)

df.drop(df[df["Transmission"]=="sedan"].index, inplace=True)

# %%
df["Transmission"].value_counts()
# Out:
# Transmission
# automatic    475915
# manual        17544
# Name: count, dtype: int64

# %%
df["Transmission"].unique()
# Out:
# array(['automatic', nan, 'manual'], dtype=object)

# %%
df["Transmission"].fillna("unknown",inplace = True)

# %%
df["Transmission"].unique()
# Out:
# array(['automatic', 'unknown', 'manual'], dtype=object)

# %%
df["Transmission"].isnull().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()

Null_Counts = df.isnull().sum()
Null_percentage = df.isnull().sum()/len(df) * 100

print(f"Null Counts:{Null_Counts}")
print(f"Null %age:{Null_percentage}")
# Out:
# Null Counts:MFG Year                0
# Brand               10301
# Model               10399
# Designation         10651
# Body Type           13195
# Transmission            0
# State                   0
# Condition           11794
# Odometer_reading       94
# Exterior_color        749
# Interior_Color        749
# Seller                  0
# MMR                    12
# Selling_price          12
# sale_date              12
# dtype: int64
# Null %age:MFG Year            0.000000
# Brand               1.843378
# Model               1.860915
# Designation         1.906011
# Body Type           2.361263
# Transmission        0.000000
# State               0.000000
# Condition           2.110553
# Odometer_reading    0.016821
# Exterior_color      0.134035
# Interior_Color      0.134035
# Seller              0.000000
# MMR                 0.002147
# Selling_price       0.002147
# sale_date           0.002147
# dtype: float64

# %%
df["Body Type"].value_counts()
# Out:
# Body Type
# Sedan          199437
# SUV            119292
# sedan           41906
# suv             24552
# Hatchback       21380
#                 ...
# g37 coupe           1
# cab plus 4          1
# CTS-V Wagon         1
# Ram Van             1
# cts wagon           1
# Name: count, Length: 86, dtype: int64

# %%
df["Body Type"].unique()
# Out:
# array(['SUV', 'Sedan', 'Convertible', 'Coupe', 'Wagon', 'Hatchback',
#        'Crew Cab', 'G Coupe', 'G Sedan', 'Elantra Coupe', 'Genesis Coupe',
#        'Minivan', nan, 'Van', 'Double Cab', 'CrewMax Cab', 'Access Cab',
#        'King Cab', 'SuperCrew', 'CTS Coupe', 'Extended Cab',
#        'E-Series Van', 'SuperCab', 'Regular Cab', 'G Convertible', 'Koup',
#        'Quad Cab', 'CTS-V Coupe', 'sedan', 'G37 Convertible', 'Club Cab',
#        'Xtracab', 'Q60 Convertible', 'CTS Wagon', 'convertible',
#        'G37 Coupe', 'Mega Cab', 'Cab Plus 4', 'Q60 Coupe', 'Cab Plus',
#        'Beetle Convertible', 'TSX Sport Wagon', 'Promaster Cargo Van',
#        'GranTurismo Convertible', 'CTS-V Wagon', 'Ram Van', 'minivan',
#        'suv', 'Transit Van', 'van', 'regular-cab', 'g sedan', 'g coupe',
#        'hatchback', 'king cab', 'supercrew', 'g convertible', 'coupe',
#        'crew cab', 'wagon', 'double cab', 'e-series van', 'regular cab',
# ...

# %%
df["Body Type"] = df["Body Type"].str.lower().str.strip()

# %%
df["Body Type"].unique()
# Out:
# array(['suv', 'sedan', 'convertible', 'coupe', 'wagon', 'hatchback',
#        'crew cab', 'g coupe', 'g sedan', 'elantra coupe', 'genesis coupe',
#        'minivan', nan, 'van', 'double cab', 'crewmax cab', 'access cab',
#        'king cab', 'supercrew', 'cts coupe', 'extended cab',
#        'e-series van', 'supercab', 'regular cab', 'g convertible', 'koup',
#        'quad cab', 'cts-v coupe', 'g37 convertible', 'club cab',
#        'xtracab', 'q60 convertible', 'cts wagon', 'g37 coupe', 'mega cab',
#        'cab plus 4', 'q60 coupe', 'cab plus', 'beetle convertible',
#        'tsx sport wagon', 'promaster cargo van',
#        'granturismo convertible', 'cts-v wagon', 'ram van', 'transit van',
#        'regular-cab'], dtype=object)

# %%
df["Body Type"].replace({
    "g coupe": "coupe",
    "g37 coupe": "coupe",
    "q60 coupe": "coupe",
    "genesis coupe": "coupe",
    "elantra coupe": "coupe",
    "cts coupe": "coupe",
    "cts-v coupe": "coupe",

    "g convertible": "convertible",
    "g37 convertible": "convertible",
    "q60 convertible": "convertible",
    "beetle convertible": "convertible",
    "granturismo convertible": "convertible",

    "cts wagon": "wagon",
    "cts-v wagon": "wagon",
    "tsx sport wagon": "wagon"
}, inplace=True)

# %%
df["Body Type"].unique()
# Out:
# array(['suv', 'sedan', 'convertible', 'coupe', 'wagon', 'hatchback',
#        'crew cab', 'g sedan', 'minivan', nan, 'van', 'double cab',
#        'crewmax cab', 'access cab', 'king cab', 'supercrew',
#        'extended cab', 'e-series van', 'supercab', 'regular cab', 'koup',
#        'quad cab', 'club cab', 'xtracab', 'mega cab', 'cab plus 4',
#        'cab plus', 'promaster cargo van', 'ram van', 'transit van',
#        'regular-cab'], dtype=object)

# %%
df["Body Type"].fillna("unknown",inplace = True)

# %%
df["Body Type"].isnull().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()

Null_Counts = df.isnull().sum()
Null_percentage = df.isnull().sum()/len(df) * 100

print(f"Null Counts:{Null_Counts}")
print(f"Null %age:{Null_percentage}")
# Out:
# Null Counts:MFG Year                0
# Brand               10301
# Model               10399
# Designation         10651
# Body Type               0
# Transmission            0
# State                   0
# Condition           11794
# Odometer_reading       94
# Exterior_color        749
# Interior_Color        749
# Seller                  0
# MMR                    12
# Selling_price          12
# sale_date              12
# dtype: int64
# Null %age:MFG Year            0.000000
# Brand               1.843378
# Model               1.860915
# Designation         1.906011
# Body Type           0.000000
# Transmission        0.000000
# State               0.000000
# Condition           2.110553
# Odometer_reading    0.016821
# Exterior_color      0.134035
# Interior_Color      0.134035
# Seller              0.000000
# MMR                 0.002147
# Selling_price       0.002147
# sale_date           0.002147
# dtype: float64

# %%
df["Condition"].unique()
# Out:
# array([ 5., 45., 41., 43.,  1., 34.,  2., 42.,  3., 48., nan, 49., 17.,
#        19., 29., 38., 44., 47., 32.,  4., 25., 37., 39., 31., 28., 46.,
#        36., 35., 26., 21., 22., 27., 24., 33., 23., 15., 16., 18., 12.,
#        14., 11., 13.])

# %%
df["Condition"].value_counts()
# Out:
# Condition
# 19.0    42281
# 35.0    26750
# 37.0    25938
# 44.0    25514
# 43.0    24937
# 42.0    24328
# 36.0    23144
# 41.0    23073
# 2.0     20790
# 4.0     19922
# 39.0    19920
# 28.0    19178
# 29.0    18928
# 38.0    18723
# 34.0    17398
# 27.0    16351
# 49.0    13099
# 48.0    12712
# 46.0    12634
# 25.0    12561
# 45.0    12313
# 26.0    11912
# 47.0    11363
# 5.0     11222
# 3.0     10803
# 33.0    10619
# 32.0     9962
# 24.0     9326
# 31.0     9222
# 21.0     9199
# 23.0     8188
# 1.0      7364
# 22.0     6057
# 18.0      323
# 17.0      243
# 16.0      178
# 15.0      144
# 14.0      134
# 12.0       95
# 11.0       87
# 13.0       82
# Name: count, dtype: int64

# %%
mode = df["Condition"].mode()[0]
df["Condition"].fillna(mode,inplace = True)
print(mode)
# Out:
# 19.0

# %%
df["Condition"].isnull().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()

Null_Counts = df.isnull().sum()
Null_percentage = df.isnull().sum()/len(df) * 100

print(f"Null Counts:{Null_Counts}")
print(f"Null %age:{Null_percentage}")
# Out:
# Null Counts:MFG Year                0
# Brand               10301
# Model               10399
# Designation         10651
# Body Type               0
# Transmission            0
# State                   0
# Condition               0
# Odometer_reading       94
# Exterior_color        749
# Interior_Color        749
# Seller                  0
# MMR                    12
# Selling_price          12
# sale_date              12
# dtype: int64
# Null %age:MFG Year            0.000000
# Brand               1.843378
# Model               1.860915
# Designation         1.906011
# Body Type           0.000000
# Transmission        0.000000
# State               0.000000
# Condition           0.000000
# Odometer_reading    0.016821
# Exterior_color      0.134035
# Interior_Color      0.134035
# Seller              0.000000
# MMR                 0.002147
# Selling_price       0.002147
# sale_date           0.002147
# dtype: float64

# %%
df[df["Brand"].isnull()]
# Out:
#         MFG Year Brand Model Designation Body Type Transmission State  \
# 742         2012   NaN   NaN         NaN   unknown    automatic    ca
# 747         2012   NaN   NaN         NaN   unknown    automatic    ca
# 766         2012   NaN   NaN         NaN   unknown    automatic    ca
# 798         2012   NaN   NaN         NaN   unknown    automatic    ca
# 803         2012   NaN   NaN         NaN   unknown    automatic    ca
# ...          ...   ...   ...         ...       ...          ...   ...
# 558545      2000   NaN   NaN         NaN   unknown    automatic    ma
# 558617      2007   NaN   NaN         NaN   unknown    automatic    pa
# 558736      2011   NaN   NaN         NaN   unknown    automatic    nv
# 558773      2005   NaN   NaN         NaN   unknown    automatic    tx
# 558776      2013   NaN   NaN         NaN   unknown    automatic    ga
#
#         Condition  Odometer_reading Exterior_color Interior_Color  \
# ...

# %%
df.dropna(subset = ["Brand"],how="all",inplace = True)

# %%
df["Brand"].isnull().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()

Null_Counts = df.isnull().sum()
Null_percentage = df.isnull().sum()/len(df) * 100

print(f"Null Counts:{Null_Counts}")
print(f"Null %age:{Null_percentage}")
# Out:
# Null Counts:MFG Year              0
# Brand                 0
# Model                98
# Designation         350
# Body Type             0
# Transmission          0
# State                 0
# Condition             0
# Odometer_reading     90
# Exterior_color      734
# Interior_Color      734
# Seller                0
# MMR                  12
# Selling_price        12
# sale_date            12
# dtype: int64
# Null %age:MFG Year            0.000000
# Brand               0.000000
# Model               0.017867
# Designation         0.063809
# Body Type           0.000000
# Transmission        0.000000
# State               0.000000
# Condition           0.000000
# Odometer_reading    0.016408
# Exterior_color      0.133817
# Interior_Color      0.133817
# Seller              0.000000
# MMR                 0.002188
# Selling_price       0.002188
# sale_date           0.002188
# dtype: float64

# %%
df[df["Model"].isnull()]
# Out:
#         MFG Year Brand Model               Designation Body Type Transmission  \
# 72          2014   BMW   NaN                     750Li     sedan    automatic
# 31262       2014   BMW   NaN                      750i     sedan    automatic
# 61951       2014   BMW   NaN              750Li xDrive     sedan    automatic
# 61955       2014   BMW   NaN              750Li xDrive     sedan    automatic
# 61956       2014   BMW   NaN                      750i     sedan    automatic
# ...          ...   ...   ...                       ...       ...          ...
# 546744      2014   BMW   NaN              750Li xDrive     sedan    automatic
# 549010      2014   BMW   NaN              750Li xDrive     sedan    automatic
# 549011      2014   BMW   NaN                     750Li     sedan    automatic
# 552124      2015  Audi   NaN  2.0 TFSI Premium quattro     sedan    automatic
# 553665      2015  Audi   NaN  2.0 TFSI Premium quattro     sedan    automatic
#
# ...

# %%
df["Model"].fillna("unknown",inplace = True)

# %%
df[df["Model"].isnull()]
# Out:
# Empty DataFrame
# Columns: [MFG Year, Brand, Model, Designation, Body Type, Transmission, State, Condition, Odometer_reading, Exterior_color, Interior_Color, Seller, MMR, Selling_price, sale_date]
# Index: []

# %%
df.isnull().sum()

Null_Counts = df.isnull().sum()
Null_percentage = df.isnull().sum()/len(df) * 100

print(f"Null Counts:{Null_Counts}")
print(f"Null %age:{Null_percentage}")
# Out:
# Null Counts:MFG Year              0
# Brand                 0
# Model                 0
# Designation         350
# Body Type             0
# Transmission          0
# State                 0
# Condition             0
# Odometer_reading     90
# Exterior_color      734
# Interior_Color      734
# Seller                0
# MMR                  12
# Selling_price        12
# sale_date            12
# dtype: int64
# Null %age:MFG Year            0.000000
# Brand               0.000000
# Model               0.000000
# Designation         0.063809
# Body Type           0.000000
# Transmission        0.000000
# State               0.000000
# Condition           0.000000
# Odometer_reading    0.016408
# Exterior_color      0.133817
# Interior_Color      0.133817
# Seller              0.000000
# MMR                 0.002188
# Selling_price       0.002188
# sale_date           0.002188
# dtype: float64

# %%
df["Designation"].fillna("unknown",inplace = True)

# %%
df.isnull().sum()

Null_Counts = df.isnull().sum()
Null_percentage = df.isnull().sum()/len(df) * 100

print(f"Null Counts:{Null_Counts}")
print(f"Null %age:{Null_percentage}")
# Out:
# Null Counts:MFG Year              0
# Brand                 0
# Model                 0
# Designation           0
# Body Type             0
# Transmission          0
# State                 0
# Condition             0
# Odometer_reading     90
# Exterior_color      734
# Interior_Color      734
# Seller                0
# MMR                  12
# Selling_price        12
# sale_date            12
# dtype: int64
# Null %age:MFG Year            0.000000
# Brand               0.000000
# Model               0.000000
# Designation         0.000000
# Body Type           0.000000
# Transmission        0.000000
# State               0.000000
# Condition           0.000000
# Odometer_reading    0.016408
# Exterior_color      0.133817
# Interior_Color      0.133817
# Seller              0.000000
# MMR                 0.002188
# Selling_price       0.002188
# sale_date           0.002188
# dtype: float64

# %%
df["Odometer_reading"].mode()
# Out:
# 0    1.0
# Name: Odometer_reading, dtype: float64

# %%
df.dropna(subset = ["Odometer_reading"],inplace = True)

# %%
df.isnull().sum()

Null_Counts = df.isnull().sum()
Null_percentage = df.isnull().sum()/len(df) * 100

print(f"Null Counts:{Null_Counts}")
print(f"Null %age:{Null_percentage}")
# Out:
# Null Counts:MFG Year              0
# Brand                 0
# Model                 0
# Designation           0
# Body Type             0
# Transmission          0
# State                 0
# Condition             0
# Odometer_reading      0
# Exterior_color      727
# Interior_Color      727
# Seller                0
# MMR                  12
# Selling_price        12
# sale_date            12
# dtype: int64
# Null %age:MFG Year            0.000000
# Brand               0.000000
# Model               0.000000
# Designation         0.000000
# Body Type           0.000000
# Transmission        0.000000
# State               0.000000
# Condition           0.000000
# Odometer_reading    0.000000
# Exterior_color      0.132563
# Interior_Color      0.132563
# Seller              0.000000
# MMR                 0.002188
# Selling_price       0.002188
# sale_date           0.002188
# dtype: float64

# %%
df.dropna(subset = ["Exterior_color"],inplace = True)
df.dropna(subset = ["Interior_Color"],inplace = True)
df.dropna(subset = ["MMR"],inplace = True)
df.dropna(subset = ["Selling_price"],inplace = True)
df.dropna(subset = ["sale_date"],inplace = True)

# %%
df.isnull().sum()

Null_Counts = df.isnull().sum()
Null_percentage = df.isnull().sum()/len(df) * 100

print(f"Null Counts:{Null_Counts}")
print(f"Null %age:{Null_percentage}")
# Out:
# Null Counts:MFG Year            0
# Brand               0
# Model               0
# Designation         0
# Body Type           0
# Transmission        0
# State               0
# Condition           0
# Odometer_reading    0
# Exterior_color      0
# Interior_Color      0
# Seller              0
# MMR                 0
# Selling_price       0
# sale_date           0
# dtype: int64
# Null %age:MFG Year            0.0
# Brand               0.0
# Model               0.0
# Designation         0.0
# Body Type           0.0
# Transmission        0.0
# State               0.0
# Condition           0.0
# Odometer_reading    0.0
# Exterior_color      0.0
# Interior_Color      0.0
# Seller              0.0
# MMR                 0.0
# Selling_price       0.0
# sale_date           0.0
# dtype: float64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# MFG Year              int64
# Brand                object
# Model                object
# Designation          object
# Body Type            object
# Transmission         object
# State                object
# Condition           float64
# Odometer_reading    float64
# Exterior_color       object
# Interior_Color       object
# Seller               object
# MMR                 float64
# Selling_price       float64
# sale_date            object
# dtype: object

# %%
df["Condition"] =  df["Condition"].astype(int)
df["Condition"].dtype
# Out:
# dtype('int64')

# %%
df["sale_date"] = pd.to_datetime(df["sale_date"] ,utc=True)

# %%
df["sale_date"].dtype
# Out:
# datetime64[ns, UTC]

# %%
df["sale_year"] = df["sale_date"].dt.year
df["sale_month"] = df["sale_date"].dt.month
df["sale_day"] = df["sale_date"].dt.day
df["sale_time"] = df["sale_date"].dt.time

# %%
df.dtypes
# Out:
# MFG Year                          int64
# Brand                            object
# Model                            object
# Designation                      object
# Body Type                        object
# Transmission                     object
# State                            object
# Condition                         int64
# Odometer_reading                float64
# Exterior_color                   object
# Interior_Color                   object
# Seller                           object
# MMR                             float64
# Selling_price                   float64
# sale_date           datetime64[ns, UTC]
# sale_year                         int32
# sale_month                        int32
# sale_day                          int32
# sale_time                        object
# dtype: object

# %%
df.head()
# Out:
#    MFG Year  Brand                Model Designation Body Type Transmission  \
# 0      2015    Kia              Sorento          LX       suv    automatic
# 1      2015    Kia              Sorento          LX       suv    automatic
# 2      2014    BMW             3 Series  328i SULEV     sedan    automatic
# 3      2015  Volvo                  S60          T5     sedan    automatic
# 4      2014    BMW  6 Series Gran Coupe        650i     sedan    automatic
#
#   State  Condition  Odometer_reading Exterior_color Interior_Color  \
# 0    ca          5           16639.0          white          black
# 1    ca          5            9393.0          white          beige
# 2    ca         45            1331.0           gray          black
# 3    ca         41           14282.0          white          black
# 4    ca         43            2641.0           gray          black
#
#                                    Seller      MMR  Selling_price  \
# ...

# %%
df[df["MFG Year"] > df["sale_year"]]
# Out:
#        MFG Year      Brand    Model Designation Body Type Transmission State  \
# 0          2015        Kia  Sorento          LX       suv    automatic    ca
# 1          2015        Kia  Sorento          LX       suv    automatic    ca
# 5          2015     Nissan   Altima       2.5 S     sedan    automatic    ca
# 11         2015        Kia   Optima          LX     sedan    automatic    ca
# 13         2015        Kia  Sorento          LX       suv    automatic    ca
# ...         ...        ...      ...         ...       ...          ...   ...
# 69268      2015     Nissan   Altima       2.5 S     sedan      unknown    pa
# 70513      2015  Chevrolet    Tahoe         LTZ       suv    automatic    ne
# 70515      2015   Chrysler      200     Limited     sedan    automatic    in
# 73093      2015       Ford   Fusion          SE     sedan    automatic    tx
# 73094      2015    Hyundai   Sonata          SE     sedan    automatic    ca
#
# ...

# %%
(df["MFG Year"] > df["sale_year"]).sum()
# Out:
# np.int64(201)

# %%
df.drop(df[df["MFG Year"] > df["sale_year"]].index, inplace=True)

# %%
(df["MFG Year"] > df["sale_year"]).sum()
# Out:
# np.int64(0)

# %%
df["MFG Year"].unique()
# Out:
# array([2014, 2015, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005,
#        2004, 2003, 2002, 2001, 2000, 1999, 1998, 1995, 1996, 1997, 1987,
#        1994, 1993, 1992, 1989, 1991, 1990, 1986, 1985, 1984])

# %%
df["Brand"].unique()
# Out:
# array(['BMW', 'Volvo', 'Chevrolet', 'Audi', 'Ford', 'Buick', 'Cadillac',
#        'Acura', 'Kia', 'Nissan', 'Hyundai', 'Infiniti', 'Jeep',
#        'Mercedes-Benz', 'Lexus', 'Mitsubishi', 'Mazda', 'MINI',
#        'Land Rover', 'Lincoln', 'lincoln', 'Jaguar', 'Volkswagen',
#        'Toyota', 'Subaru', 'Scion', 'Porsche', 'bmw', 'Dodge', 'FIAT',
#        'Chrysler', 'ford', 'Ferrari', 'Honda', 'GMC', 'mitsubishi', 'Ram',
#        'smart', 'chevrolet', 'Bentley', 'chrysler', 'pontiac', 'Pontiac',
#        'Saturn', 'Maserati', 'Mercury', 'HUMMER', 'landrover', 'cadillac',
#        'land rover', 'mercedes', 'mazda', 'toyota', 'lexus', 'gmc truck',
#        'honda', 'nissan', 'porsche', 'Saab', 'Suzuki', 'dodge', 'subaru',
#        'Oldsmobile', 'oldsmobile', 'hyundai', 'jeep', 'Isuzu', 'dodge tk',
#        'Geo', 'acura', 'volkswagen', 'suzuki', 'kia', 'audi',
#        'Rolls-Royce', 'gmc', 'maserati', 'mazda tk', 'mercury', 'buick',
# ...

# %%
df["Brand"] = df["Brand"].str.lower().str.strip()

# %%
df["Brand"] = df["Brand"].replace({
    "bmw": "BMW",
    "ford": "Ford",
    "chevrolet": "Chevrolet",
    "audi": "Audi",
    "buick": "Buick",
    "cadillac": "Cadillac",
    "acura": "Acura",
    "kia": "Kia",
    "nissan": "Nissan",
    "hyundai": "Hyundai",
    "infiniti": "Infiniti",
    "jeep": "Jeep",
    "lexus": "Lexus",
    "mitsubishi": "Mitsubishi",
    "mazda": "Mazda",
    "toyota": "Toyota",
    "subaru": "Subaru",
    "honda": "Honda",
    "gmc": "GMC",
    "pontiac": "Pontiac",
    "mercury": "Mercury",
    "oldsmobile": "Oldsmobile",
    "suzuki": "Suzuki",
    "volkswagen": "Volkswagen",

    "landrover": "Land Rover",
    "land rover": "Land Rover",

    "mercedes": "Mercedes-Benz",
    "mercedes-b": "Mercedes-Benz",

    "vw": "Volkswagen",

    "gmc truck": "GMC",
    "chev truck": "Chevrolet",
    "ford truck": "Ford",
    "ford tk": "Ford",
    "mazda tk": "Mazda",
    "hyundai tk": "Hyundai",
    "dodge tk": "Dodge"
})

# %%
df["Brand"].unique()
# Out:
# array(['BMW', 'volvo', 'Chevrolet', 'Audi', 'Ford', 'Buick', 'Cadillac',
#        'Acura', 'Kia', 'Nissan', 'Hyundai', 'Infiniti', 'Jeep',
#        'mercedes-benz', 'Lexus', 'Mitsubishi', 'Mazda', 'mini',
#        'Land Rover', 'lincoln', 'jaguar', 'Volkswagen', 'Toyota',
#        'Subaru', 'scion', 'porsche', 'dodge', 'fiat', 'chrysler',
#        'ferrari', 'Honda', 'GMC', 'ram', 'smart', 'bentley', 'Pontiac',
#        'saturn', 'maserati', 'Mercury', 'hummer', 'Mercedes-Benz', 'saab',
#        'Suzuki', 'Oldsmobile', 'isuzu', 'Dodge', 'geo', 'rolls-royce',
#        'daewoo', 'plymouth', 'tesla', 'airstream', 'dot', 'aston martin',
#        'fisker', 'lamborghini', 'lotus'], dtype=object)

# %%
df["State"].unique()
# Out:
# array(['ca', 'mn', 'wi', 'fl', 'nj', 'pa', 'oh', 'tx', 'sc', 'va', 'in',
#        'il', 'tn', 'mi', 'az', 'co', 'ut', 'ga', 'mo', 'ny', 'ne', 'nv',
#        'ma', 'pr', 'nc', 'or', 'md', 'la', 'wa', 'hi', 'qc', 'ab', 'on',
#        'ok', 'ms', 'nm', 'al', 'ns'], dtype=object)

# %%
df.info()
df.describe()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 547480 entries, 2 to 558836
# Data columns (total 19 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   MFG Year          547480 non-null  int64
#  1   Brand             547480 non-null  object
#  2   Model             547480 non-null  object
#  3   Designation       547480 non-null  object
#  4   Body Type         547480 non-null  object
#  5   Transmission      547480 non-null  object
#  6   State             547480 non-null  object
#  7   Condition         547480 non-null  int64
#  8   Odometer_reading  547480 non-null  float64
#  9   Exterior_color    547480 non-null  object
#  10  Interior_Color    547480 non-null  object
#  11  Seller            547480 non-null  object
#  12  MMR               547480 non-null  float64
#  13  Selling_price     547480 non-null  float64
#  14  sale_date         547480 non-null  datetime64[ns, UTC]
# ...

# %%
df.to_csv("cleaned_car_prices.csv", index=False)
