# %%
#Importing Libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns


import warnings

warnings.filterwarnings("ignore")

# %matplotlib inline

# %%
# Loading the Dataset

df = pd.read_csv("cleaned_car_prices.csv")

# %%
df.shape
# Out:
# (547480, 19)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 547480 entries, 0 to 547479
# Data columns (total 19 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   MFG Year          547480 non-null  int64
#  1   Brand             547480 non-null  object
#  2   Model             547480 non-null  object
#  3   Designation       547480 non-null  object
#  4   Body Type         547480 non-null  object
#  5   Transmission      547480 non-null  object
#  6   State             547480 non-null  object
#  7   Condition         547480 non-null  int64
#  8   Odometer_reading  547480 non-null  float64
#  9   Exterior_color    547480 non-null  object
#  10  Interior_Color    547480 non-null  object
#  11  Seller            547480 non-null  object
#  12  MMR               547480 non-null  float64
#  13  Selling_price     547480 non-null  float64
#  14  sale_date         547480 non-null  object
#  15  sale_year         547480 non-null  int64
# ...

# %%
df.describe()
# Out:
#             MFG Year      Condition  Odometer_reading            MMR  \
# count  547480.000000  547480.000000     547480.000000  547480.000000
# mean     2010.112612      30.527225      67573.652095   13842.517078
# std         3.907621      13.338649      52894.559802    9629.058026
# min      1984.000000       1.000000          1.000000      25.000000
# 25%      2008.000000      23.000000      28175.000000    7275.000000
# 50%      2012.000000      34.000000      51460.000000   12350.000000
# 75%      2013.000000      41.000000      97968.000000   18400.000000
# max      2015.000000      49.000000     999999.000000  182000.000000
#
#        Selling_price      sale_year     sale_month      sale_day
# count  547480.000000  547480.000000  547480.000000  547480.00000
# mean    13683.879170    2014.902765       3.809405      14.63469
# std      9699.891886       0.296277       3.241998       8.58644
# min         1.000000    2014.000000       1.000000       1.00000
# ...

# %% [markdown]
# # Describing Selling Prices

# %%
df["Selling_price"].describe()
# Out:
# count    547480.000000
# mean      13683.879170
# std        9699.891886
# min           1.000000
# 25%        7000.000000
# 50%       12200.000000
# 75%       18250.000000
# max      230000.000000
# Name: Selling_price, dtype: float64

# %% [markdown]
# # Histplot For Selling Price

# %%
sns.histplot(df["Selling_price"], kde=True)
plt.show()

# %% [markdown]
# # Histplot for Vehicle Age

# %%
df["Vehicle_Age"] = df["sale_year"] - df["MFG Year"]

# %% [markdown]
# # Scatter Plot for "Vehicle_Age" vs "Selling_price"

# %%
df["Vehicle_Age"] = df["sale_year"] - df["MFG Year"]

# %%
df.plot.scatter(x="Vehicle_Age", y="Selling_price")
# Out:
# <Axes: xlabel='Vehicle_Age', ylabel='Selling_price'>
